# %%
import pandas as pd
import warnings
from IPython.utils import io
import sys
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %% [markdown]
# ## **Load, format, and examine 'prds_hosp10_yr' sas7bdat files**
# ## Concatenate files into a single dataframe (main_df) and join with the crosswalk file

# %%
with io.capture_output() as captured: prds_2010_df = pd.read_sas('~/GitHub/HCRIS-databuilder/hosp10-sas/prds_hosp10_yr2010.sas7bdat')
prds_2010_df['File Date'] = ['2010'] * prds_2010_df.shape[0]
print('prds_hosp10_yr2010: (rows, columns) =', prds_2010_df.shape)

with io.capture_output() as captured: prds_2011_df = pd.read_sas('~/GitHub/HCRIS-databuilder/hosp10-sas/prds_hosp10_yr2011.sas7bdat')
prds_2011_df['File Date'] = ['2011'] * prds_2011_df.shape[0]
print('prds_hosp10_yr2011: (rows, columns) =', prds_2011_df.shape)

with io.capture_output() as captured: prds_2012_df = pd.read_sas('~/GitHub/HCRIS-databuilder/hosp10-sas/prds_hosp10_yr2012.sas7bdat')
prds_2012_df['File Date'] = ['2012'] * prds_2012_df.shape[0]
print('prds_hosp10_yr2012: (rows, columns) =', prds_2012_df.shape)

with io.capture_output() as captured: prds_2013_df = pd.read_sas('~/GitHub/HCRIS-databuilder/hosp10-sas/prds_hosp10_yr2013.sas7bdat')
prds_2013_df['File Date'] = ['2013'] * prds_2013_df.shape[0]
print('prds_hosp10_yr2013: (rows, columns) =', prds_2013_df.shape)

with io.capture_output() as captured: prds_2014_df = pd.read_sas('~/GitHub/HCRIS-databuilder/hosp10-sas/prds_hosp10_yr2014.sas7bdat')
prds_2014_df['File Date'] = ['2014'] * prds_2014_df.shape[0]
print('prds_hosp10_yr2014: (rows, columns) =', prds_2014_df.shape)

with io.capture_output() as captured: prds_2015_df = pd.read_sas('~/GitHub/HCRIS-databuilder/hosp10-sas/prds_hosp10_yr2015.sas7bdat')
prds_2015_df['File Date'] = ['2015'] * prds_2015_df.shape[0]
print('prds_hosp10_yr2015: (rows, columns) =', prds_2015_df.shape)

with io.capture_output() as captured: prds_2016_df = pd.read_sas('~/GitHub/HCRIS-databuilder/hosp10-sas/prds_hosp10_yr2016.sas7bdat')
prds_2016_df['File Date'] = ['2016'] * prds_2016_df.shape[0]
print('prds_hosp10_yr2016: (rows, columns) =', prds_2016_df.shape)

with io.capture_output() as captured: prds_2017_df = pd.read_sas('~/GitHub/HCRIS-databuilder/hosp10-sas/prds_hosp10_yr2017.sas7bdat')
prds_2017_df['File Date'] = ['2017'] * prds_2017_df.shape[0]
print('prds_hosp10_yr2017: (rows, columns) =', prds_2017_df.shape)

with io.capture_output() as captured: prds_2018_df = pd.read_sas('~/GitHub/HCRIS-databuilder/hosp10-sas/prds_hosp10_yr2018.sas7bdat')
prds_2018_df['File Date'] = ['2018'] * prds_2018_df.shape[0]
print('prds_hosp10_yr2018: (rows, columns) =', prds_2018_df.shape)

with io.capture_output() as captured: prds_2019_df = pd.read_sas('~/GitHub/HCRIS-databuilder/hosp10-sas/prds_hosp10_yr2019.sas7bdat')
prds_2019_df['File Date'] = ['2019'] * prds_2019_df.shape[0]
print('prds_hosp10_yr2019: (rows, columns) =', prds_2019_df.shape)

with io.capture_output() as captured: prds_2020_df = pd.read_sas('~/GitHub/HCRIS-databuilder/hosp10-sas/prds_hosp10_yr2020.sas7bdat')
prds_2020_df['File Date'] = ['2020'] * prds_2020_df.shape[0]
print('prds_hosp10_yr2020: (rows, columns) =', prds_2020_df.shape)

with io.capture_output() as captured: prds_2021_df = pd.read_sas('~/GitHub/HCRIS-databuilder/hosp10-sas/prds_hosp10_yr2021.sas7bdat')
prds_2021_df['File Date'] = ['2021'] * prds_2021_df.shape[0]
print('prds_hosp10_yr2021: (rows, columns) =', prds_2021_df.shape)

with io.capture_output() as captured: prds_2022_df = pd.read_sas('~/GitHub/HCRIS-databuilder/hosp10-sas/prds_hosp10_yr2022.sas7bdat')
prds_2022_df['File Date'] = ['2022'] * prds_2022_df.shape[0]
print('prds_hosp10_yr2022: (rows, columns) =', prds_2022_df.shape)
# Out:
# prds_hosp10_yr2010: (rows, columns) = (2323, 5522)
# prds_hosp10_yr2011: (rows, columns) = (6150, 5522)
# prds_hosp10_yr2012: (rows, columns) = (6227, 5522)
# prds_hosp10_yr2013: (rows, columns) = (6248, 5522)
# prds_hosp10_yr2014: (rows, columns) = (6250, 5522)
# prds_hosp10_yr2015: (rows, columns) = (6257, 5522)
# prds_hosp10_yr2016: (rows, columns) = (6211, 5522)
# prds_hosp10_yr2017: (rows, columns) = (6173, 5522)
# prds_hosp10_yr2018: (rows, columns) = (6159, 5522)
# prds_hosp10_yr2019: (rows, columns) = (6118, 5522)
# prds_hosp10_yr2020: (rows, columns) = (6050, 5522)
# prds_hosp10_yr2021: (rows, columns) = (2597, 5522)
# prds_hosp10_yr2022: (rows, columns) = (5, 5522)

# %%
main_df = pd.concat([prds_2021_df, prds_2020_df, prds_2019_df, prds_2018_df, prds_2017_df, prds_2016_df, 
                     prds_2015_df, prds_2014_df, prds_2013_df, prds_2012_df, prds_2011_df, prds_2010_df,
                     ], ignore_index=True)

main_df = main_df.applymap(lambda x: x.decode() if isinstance(x, bytes) else x)
main_df = main_df.dropna(axis=1, how='all')
main_df.head()
# Out:
#    rpt_rec_num prvdr_num fi_num rpt_stus_cd fi_creat_dt  fy_bgn_dt  fy_end_dt  \
# 0     692984.0    441314  10001           1  2021-06-24 2020-10-01 2020-12-31
# 1     693446.0    420073  11001           1  2021-07-01 2020-10-01 2021-01-31
# 2     695160.0    353026  03001           2  2021-08-06 2020-10-01 2020-12-31
# 3     695329.0    111314  10001           1  2021-08-09 2020-10-01 2020-12-31
# 4     695374.0    341317  11501           1  2021-08-10 2020-10-01 2020-12-31
#
#   util_cd trnsmtl_num state st_cty_cd  census  region    proc_dt   msa  \
# 0       F           N    44     44480     6.0     4.0 2021-06-25   NaN
# 1       F           N    42     42310     5.0     4.0 2021-07-15  1760
# 2       F           N   NaN       NaN     NaN     NaN 2021-08-09   NaN
# 3       F           N    11     11410     5.0     4.0 2021-08-11   NaN
# 4       F           N    34     34840     5.0     4.0 2021-08-11  3120
#
#    A_C1_114  A_C1_4201  A_C1_4501  A_C2_114  A_C2_4201  A_C2_4501  A_C2_61  \
# 0       NaN        NaN        NaN       NaN        NaN        NaN      NaN
# 1       NaN        NaN        NaN       NaN        NaN        NaN      NaN
# 2       NaN        NaN        NaN       NaN        NaN        NaN      NaN
# 3       NaN        NaN        NaN       NaN        NaN        NaN      NaN
# 4       NaN        NaN        NaN       NaN        NaN        NaN      NaN
#
#    A_C6_4201  A_C6_4501  A_C6_61  B_1_C0_4201  B_1_C0_4501  B_1_C0_61  \
# 0        NaN        NaN      NaN          NaN          NaN        NaN
# 1        NaN        NaN      NaN          NaN          NaN        NaN
# 2        NaN        NaN      NaN          NaN          NaN        NaN
# 3        NaN        NaN      NaN          NaN          NaN        NaN
# 4        NaN        NaN      NaN          NaN          NaN        NaN
#
#    B_1_C21_109  B_1_C21_42  B_1_C21_45  B_1_C21_46  B_1_C21_94  B_1_C22_109  \
# 0          NaN         NaN         NaN         NaN         NaN          NaN
# 1          NaN         NaN         NaN         NaN         NaN          NaN
# 2          NaN         NaN         NaN         NaN         NaN          NaN
# 3          NaN         NaN         NaN         NaN         NaN          NaN
# 4          NaN         NaN         NaN         NaN         NaN          NaN
#
#    B_1_C22_110  B_1_C22_111  B_1_C22_42  B_1_C22_45  B_1_C22_46  B_1_C22_94  \
# 0          NaN          NaN         NaN         NaN         NaN         NaN
# 1          NaN          NaN         NaN         NaN         NaN         NaN
# 2          NaN          NaN         NaN         NaN         NaN         NaN
# 3          NaN          NaN         NaN         NaN         NaN         NaN
# 4          NaN          NaN         NaN         NaN         NaN         NaN
#
#    B_1_C26_4201  B_1_C26_4501  B_1_C26_61  B_2_C26_4201  B_2_C26_4501  \
# 0           NaN           NaN         NaN           NaN           NaN
# 1           NaN           NaN         NaN           NaN           NaN
# 2           NaN           NaN         NaN           NaN           NaN
# 3           NaN           NaN         NaN           NaN           NaN
# 4           NaN           NaN         NaN           NaN           NaN
#
#    C_1_C5_4201  C_1_C5_4501  C_1_C5_61  C_1_C6_100  C_1_C6_111  C_1_C6_4201  \
# 0          NaN          NaN        NaN         NaN         NaN          NaN
# 1          NaN          NaN        NaN         NaN         NaN          NaN
# 2          NaN          NaN        NaN         NaN         NaN          NaN
# 3          NaN          NaN        NaN         NaN         NaN          NaN
# 4          NaN          NaN        NaN         NaN         NaN          NaN
#
#    C_1_C6_4501  C_1_C6_61  C_1_C7_111  D3_HOS_C2_201  D3_HOS_C2_43  \
# 0          NaN        NaN         NaN            NaN           NaN
# 1          NaN        NaN         NaN            NaN           NaN
# 2          NaN        NaN         NaN            NaN           NaN
# 3          NaN        NaN         NaN            NaN           NaN
# 4          NaN        NaN         NaN            NaN           NaN
#
#    D3_HOS_C2_61  D3_HOS_C3_61  D3_IPF_C2_41  D3_IPF_C2_42  D3_IPF_C2_94  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#    D3_IPF_C3_94  D3_IRF_C2_61  D3_IRF_C3_61  D3_SNF_C2_30  D3_SNF_C2_41  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#    D3_SNF_C2_94  D3_SNF_C3_94  D_1_HOS_C4_4201  D_2_IPF_C5_94  D_4_HOS_C11_94  \
# 0           NaN           NaN              NaN            NaN             NaN
# 1           NaN           NaN              NaN            NaN             NaN
# 2           NaN           NaN              NaN            NaN             NaN
# 3           NaN           NaN              NaN            NaN             NaN
# 4           NaN           NaN              NaN            NaN             NaN
#
#    D_4_HOS_C12_94  D_4_HOS_C2_94  D_4_HOS_C3_94  D_4_IRF_C13_74  \
# 0             NaN            NaN            NaN             NaN
# 1             NaN            NaN            NaN             NaN
# 2             NaN            NaN            NaN             NaN
# 3             NaN            NaN            NaN             NaN
# 4             NaN            NaN            NaN             NaN
#
#    D_4_SNF_C11_74  D_4_SNF_C13_200  D_5_HOS_C2_94  D_5_HOS_C3_61  \
# 0             NaN              NaN            NaN            NaN
# 1             NaN              NaN            NaN            NaN
# 2             NaN              NaN            NaN            NaN
# 3             NaN              NaN            NaN            NaN
# 4             NaN              NaN            NaN            NaN
#
#    D_5_HOS_C6_61  E1_2_HOS_C1_30  E1_2_HOS_C1_31  E1_2_HOS_C1_6  \
# 0            NaN             NaN             NaN            NaN
# 1            NaN             NaN             NaN            NaN
# 2            NaN             NaN             NaN            NaN
# 3            NaN             NaN             NaN            NaN
# 4            NaN             NaN             NaN            NaN
#
#    E1_2_HOS_C1_7  E2_SWSNF_C1_7  E3_1_HOS_C1_20  E3_2_HOS_C1_13  \
# 0            NaN            NaN             NaN             NaN
# 1            NaN            NaN             NaN             NaN
# 2            NaN            NaN             NaN             NaN
# 3            NaN            NaN             NaN             NaN
# 4            NaN            NaN             NaN             NaN
#
#    E3_2_HOS_C1_29  E3_2_HOS_C1_3101  E3_2_IPF_C1_13  E3_2_IPF_C1_15  \
# 0             NaN               NaN             NaN             NaN
# 1             NaN               NaN             NaN             NaN
# 2             NaN               NaN             NaN             NaN
# 3             NaN               NaN             NaN             NaN
# 4             NaN               NaN             NaN             NaN
#
#    E3_2_IPF_C1_29  E3_2_IPF_C1_3101  E3_2_IPF_C1_33  E3_3_HOS_C1_16  \
# 0             NaN               NaN             NaN             NaN
# 1             NaN               NaN             NaN             NaN
# 2             NaN               NaN             NaN             NaN
# 3             NaN               NaN             NaN             NaN
# 4             NaN               NaN             NaN             NaN
#
#    E3_3_HOS_C1_30  E3_3_HOS_C1_3201  E3_3_HOS_C1_51  E3_3_HOS_C1_52  \
# 0             NaN               NaN             NaN             NaN
# 1             NaN               NaN             NaN             NaN
# 2             NaN               NaN             NaN             NaN
# 3             NaN               NaN             NaN             NaN
# 4             NaN               NaN             NaN             NaN
#
#    E3_3_HOS_C1_53  E3_3_IRF_C1_14  E3_3_IRF_C1_16  E3_3_IRF_C1_30  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    E3_3_IRF_C1_3201  E3_3_IRF_C1_34  E3_3_IRF_C1_51  E3_3_IRF_C1_52  \
# 0               NaN             NaN             NaN             NaN
# 1               NaN             NaN             NaN             NaN
# 2               NaN             NaN             NaN             NaN
# 3               NaN             NaN             NaN             NaN
# 4               NaN             NaN             NaN             NaN
#
#    E3_3_IRF_C1_53  E3_4_HOS_C1_19  E3_4_HOS_C1_20  E3_4_HOS_C1_2201  \
# 0             NaN             NaN             NaN               NaN
# 1             NaN             NaN             NaN               NaN
# 2             NaN             NaN             NaN               NaN
# 3             NaN             NaN             NaN               NaN
# 4             NaN             NaN             NaN               NaN
#
#    E3_4_HOS_C1_4  E3_4_HOS_C1_51  E3_4_HOS_C1_52  E3_4_HOS_C1_53  \
# 0            NaN             NaN             NaN             NaN
# 1            NaN             NaN             NaN             NaN
# 2            NaN             NaN             NaN             NaN
# 3            NaN             NaN             NaN             NaN
# 4            NaN             NaN             NaN             NaN
#
#    E3_4_HOS_C1_6  E3_5_C1_15  E3_5_C1_2  E3_5_C1_7  E3_6_SNF_C1_17  \
# 0            NaN         NaN        NaN        NaN             NaN
# 1            NaN         NaN        NaN        NaN             NaN
# 2            NaN         NaN        NaN        NaN             NaN
# 3            NaN         NaN        NaN        NaN             NaN
# 4            NaN         NaN        NaN        NaN             NaN
#
#    E_A_HOS_C101_1  E_A_HOS_C101_2  E_A_HOS_C101_202  E_A_HOS_C101_48  \
# 0             NaN             NaN               NaN              NaN
# 1             NaN             NaN               NaN              NaN
# 2             NaN             NaN               NaN              NaN
# 3             NaN             NaN               NaN              NaN
# 4             NaN             NaN               NaN              NaN
#
#    E_A_HOS_C1_1  E_A_HOS_C1_2  E_A_HOS_C1_202  E_A_HOS_C1_51  E_A_HOS_C1_56  \
# 0           NaN           NaN             NaN            NaN            NaN
# 1           NaN           NaN             NaN            NaN            NaN
# 2           NaN           NaN             NaN            NaN            NaN
# 3           NaN           NaN             NaN            NaN            NaN
# 4           NaN           NaN             NaN            NaN            NaN
#
#    E_A_HOS_C1_69  E_A_HOS_C1_7089  E_A_HOS_C1_7101  E_A_HOS_C1_93  \
# 0            NaN              NaN              NaN            NaN
# 1            NaN              NaN              NaN            NaN
# 2            NaN              NaN              NaN            NaN
# 3            NaN              NaN              NaN            NaN
# 4            NaN              NaN              NaN            NaN
#
#    E_A_HOS_C1_94  E_A_HOS_C1_95  E_A_HOS_C1_96  E_B_HOS_C1_4001  \
# 0            NaN            NaN            NaN              NaN
# 1            NaN            NaN            NaN              NaN
# 2            NaN            NaN            NaN              NaN
# 3            NaN            NaN            NaN              NaN
# 4            NaN            NaN            NaN              NaN
#
#    E_B_IPF_C1_15  E_B_IPF_C1_16  E_B_IPF_C1_17  E_B_IPF_C1_20  E_B_IPF_C1_23  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    E_B_IPF_C1_4001  E_B_IPF_C1_42  E_B_IPF_C1_8  E_B_IRF_C1_15  E_B_IRF_C1_16  \
# 0              NaN            NaN           NaN            NaN            NaN
# 1              NaN            NaN           NaN            NaN            NaN
# 2              NaN            NaN           NaN            NaN            NaN
# 3              NaN            NaN           NaN            NaN            NaN
# 4              NaN            NaN           NaN            NaN            NaN
#
#    E_B_IRF_C1_17  E_B_IRF_C1_20  E_B_IRF_C1_23  E_B_IRF_C1_31  E_B_IRF_C1_38  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    E_B_IRF_C1_42  E_B_IRF_C1_8  E_B_SNF_C1_15  E_B_SNF_C1_16  E_B_SNF_C1_17  \
# 0            NaN           NaN            NaN            NaN            NaN
# 1            NaN           NaN            NaN            NaN            NaN
# 2            NaN           NaN            NaN            NaN            NaN
# 3            NaN           NaN            NaN            NaN            NaN
# 4            NaN           NaN            NaN            NaN            NaN
#
#    E_B_SNF_C1_2  E_B_SNF_C1_24  E_B_SNF_C1_26  E_B_SNF_C1_31  E_B_SNF_C1_42  \
# 0           NaN            NaN            NaN            NaN            NaN
# 1           NaN            NaN            NaN            NaN            NaN
# 2           NaN            NaN            NaN            NaN            NaN
# 3           NaN            NaN            NaN            NaN            NaN
# 4           NaN            NaN            NaN            NaN            NaN
#
#    E_B_SNF_C1_9  G2_C1_25  G2_C1_401  H3_1_HHA1_C6_3  H3_1_HHA2_C10_16  \
# 0           NaN       NaN        NaN             NaN               NaN
# 1           NaN       NaN        NaN             NaN               NaN
# 2           NaN       NaN        NaN             NaN               NaN
# 3           NaN       NaN        NaN             NaN               NaN
# 4           NaN       NaN        NaN             NaN               NaN
#
#    H3_1_HHA2_C11_15  H3_1_HHA2_C6_1  H3_1_HHA2_C6_2  H3_1_HHA2_C6_3  \
# 0               NaN             NaN             NaN             NaN
# 1               NaN             NaN             NaN             NaN
# 2               NaN             NaN             NaN             NaN
# 3               NaN             NaN             NaN             NaN
# 4               NaN             NaN             NaN             NaN
#
#    H3_1_HHA2_C6_4  H3_1_HHA2_C6_5  H3_1_HHA2_C6_6  H3_1_HHA2_C6_7  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    H3_1_HHA2_C9_15  H3_1_HHA3_C10_15  H3_1_HHA3_C5_1  H3_1_HHA3_C5_2  \
# 0              NaN               NaN             NaN             NaN
# 1              NaN               NaN             NaN             NaN
# 2              NaN               NaN             NaN             NaN
# 3              NaN               NaN             NaN             NaN
# 4              NaN               NaN             NaN             NaN
#
#    H3_1_HHA3_C5_3  H3_1_HHA3_C5_4  H3_1_HHA3_C5_5  H3_1_HHA3_C5_6  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    H3_1_HHA3_C6_1  H3_1_HHA3_C6_2  H3_1_HHA3_C6_3  H3_1_HHA3_C6_4  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    H3_1_HHA3_C6_5  H3_1_HHA3_C6_6  H3_1_HHA3_C6_7  H3_1_HHA3_C7_1  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    H3_1_HHA3_C7_2  H3_1_HHA3_C7_3  H3_1_HHA3_C7_4  H3_1_HHA3_C7_5  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    H3_1_HHA3_C7_6  H3_1_HHA3_C7_7  H3_1_HHA3_C9_15  H4_2_HHA1_C1_10  \
# 0             NaN             NaN              NaN              NaN
# 1             NaN             NaN              NaN              NaN
# 2             NaN             NaN              NaN              NaN
# 3             NaN             NaN              NaN              NaN
# 4             NaN             NaN              NaN              NaN
#
#    H4_2_HHA1_C1_11  H4_2_HHA1_C1_12  H4_2_HHA1_C1_13  H4_2_HHA1_C1_14  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    H4_2_HHA1_C1_15  H4_2_HHA1_C1_16  H4_2_HHA1_C1_17  H4_2_HHA1_C1_18  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    H4_2_HHA1_C1_22  H4_2_HHA1_C1_24  H4_2_HHA1_C1_26  H4_2_HHA1_C1_29  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    H4_2_HHA1_C1_30  H4_2_HHA1_C1_31  H4_2_HHA1_C1_3101  H4_2_HHA1_C1_32  \
# 0              NaN              NaN                NaN              NaN
# 1              NaN              NaN                NaN              NaN
# 2              NaN              NaN                NaN              NaN
# 3              NaN              NaN                NaN              NaN
# 4              NaN              NaN                NaN              NaN
#
#    H4_2_HHA1_C1_33  H4_2_HHA1_C1_34  H4_2_HHA1_C1_35  H4_2_HHA1_C2_18  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    H4_2_HHA1_C2_21  H4_2_HHA2_C1_10  H4_2_HHA2_C1_11  H4_2_HHA2_C1_12  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    H4_2_HHA2_C1_13  H4_2_HHA2_C1_14  H4_2_HHA2_C1_15  H4_2_HHA2_C1_16  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    H4_2_HHA2_C1_22  H4_2_HHA2_C1_24  H4_2_HHA2_C1_26  H4_2_HHA2_C1_29  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    H4_2_HHA2_C1_30  H4_2_HHA2_C1_31  H4_2_HHA2_C1_3101  H4_2_HHA2_C1_32  \
# 0              NaN              NaN                NaN              NaN
# 1              NaN              NaN                NaN              NaN
# 2              NaN              NaN                NaN              NaN
# 3              NaN              NaN                NaN              NaN
# 4              NaN              NaN                NaN              NaN
#
#    H4_2_HHA2_C1_33  H4_2_HHA2_C1_34  H4_2_HHA2_C2_10  H4_2_HHA2_C2_16  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    H4_2_HHA2_C2_17  H4_2_HHA2_C2_23  H4_2_HHA2_C2_25  H4_2_HHA2_C2_30  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    H4_2_HHA2_C2_3101  H4_2_HHA2_C2_33  H4_2_HHA2_C2_34  H4_2_HHA3_C1_11  \
# 0                NaN              NaN              NaN              NaN
# 1                NaN              NaN              NaN              NaN
# 2                NaN              NaN              NaN              NaN
# 3                NaN              NaN              NaN              NaN
# 4                NaN              NaN              NaN              NaN
#
#    H4_2_HHA3_C1_12  H4_2_HHA3_C1_13  H4_2_HHA3_C1_14  H4_2_HHA3_C1_15  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    H4_2_HHA3_C1_16  H4_2_HHA3_C1_22  H4_2_HHA3_C1_24  H4_2_HHA3_C1_26  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    H4_2_HHA3_C1_29  H4_2_HHA3_C1_31  H4_2_HHA3_C1_32  H4_2_HHA3_C1_33  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    H4_2_HHA3_C1_34  H4_2_HHA3_C2_10  H4_2_HHA3_C2_11  H4_2_HHA3_C2_12  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    H4_2_HHA3_C2_13  H4_2_HHA3_C2_14  H4_2_HHA3_C2_15  H4_2_HHA3_C2_16  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    H4_2_HHA3_C2_22  H4_2_HHA3_C2_24  H4_2_HHA3_C2_26  H4_2_HHA3_C2_29  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    H4_2_HHA3_C2_30  H4_2_HHA3_C2_31  H4_2_HHA3_C2_3101  H4_2_HHA3_C2_32  \
# 0              NaN              NaN                NaN              NaN
# 1              NaN              NaN                NaN              NaN
# 2              NaN              NaN                NaN              NaN
# 3              NaN              NaN                NaN              NaN
# 4              NaN              NaN                NaN              NaN
#
#    H4_2_HHA3_C2_33  H4_2_HHA3_C2_34  L_1_HOS_C1_201  L_3_HOS_C1_1  \
# 0              NaN              NaN             NaN           NaN
# 1              NaN              NaN             NaN           NaN
# 2              NaN              NaN             NaN           NaN
# 3              NaN              NaN             NaN           NaN
# 4              NaN              NaN             NaN           NaN
#
#    L_3_HOS_C1_10  L_3_HOS_C1_11  L_3_HOS_C1_12  L_3_HOS_C1_13  L_3_HOS_C1_14  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    L_3_HOS_C1_15  L_3_HOS_C1_16  L_3_HOS_C1_3  L_3_HOS_C1_4  L_3_HOS_C1_5  \
# 0            NaN            NaN           NaN           NaN           NaN
# 1            NaN            NaN           NaN           NaN           NaN
# 2            NaN            NaN           NaN           NaN           NaN
# 3            NaN            NaN           NaN           NaN           NaN
# 4            NaN            NaN           NaN           NaN           NaN
#
#    L_3_HOS_C1_6  L_3_HOS_C1_8  L_3_HOS_C1_9  S3_1_C10_1801  S3_1_C10_2001  \
# 0           NaN           NaN           NaN            NaN            NaN
# 1           NaN           NaN           NaN            NaN            NaN
# 2           NaN           NaN           NaN            NaN            NaN
# 3           NaN           NaN           NaN            NaN            NaN
# 4           NaN           NaN           NaN            NaN            NaN
#
#    S3_1_C10_23  S3_1_C11_19  S3_1_C11_21  S3_1_C11_23  S3_1_C13_18  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    S3_1_C14_1801  S3_1_C15_1801  S3_1_C2_1801  S3_1_C2_2001  S3_1_C3_1801  \
# 0            NaN            NaN           NaN           NaN           NaN
# 1            NaN            NaN           NaN           NaN           NaN
# 2            NaN            NaN           NaN           NaN           NaN
# 3            NaN            NaN           NaN           NaN           NaN
# 4            NaN            NaN           NaN           NaN           NaN
#
#    S3_1_C3_2001  S3_1_C5_20  S3_1_C5_6  S3_1_C7_1801  S3_1_C7_2001  \
# 0           NaN         NaN        NaN           NaN           NaN
# 1           NaN         NaN        NaN           NaN           NaN
# 2           NaN         NaN        NaN           NaN           NaN
# 3           NaN         NaN        NaN           NaN           NaN
# 4           NaN         NaN        NaN           NaN           NaN
#
#    S3_1_C8_1801  S3_1_C8_2001  S3_1_C9_18  S3_1_C9_20  S3_1_C9_21  S3_1_C9_23  \
# 0           NaN           NaN         NaN         NaN         NaN         NaN
# 1           NaN           NaN         NaN         NaN         NaN         NaN
# 2           NaN           NaN         NaN         NaN         NaN         NaN
# 3           NaN           NaN         NaN         NaN         NaN         NaN
# 4           NaN           NaN         NaN         NaN         NaN         NaN
#
#    S3_2_C2_14  S3_2_C2_16  S3_2_C2_18  S3_2_C3_14  S3_2_C3_1402  S3_2_C3_2551  \
# 0         NaN         NaN         NaN         NaN           NaN           NaN
# 1         NaN         NaN         NaN         NaN           NaN           NaN
# 2         NaN         NaN         NaN         NaN           NaN           NaN
# 3         NaN         NaN         NaN         NaN           NaN           NaN
# 4         NaN         NaN         NaN         NaN           NaN           NaN
#
#    S3_2_C3_2552  S3_2_C3_2553  S3_2_C4_14  S3_2_C4_16  S3_2_C4_18  S3_2_C5_14  \
# 0           NaN           NaN         NaN         NaN         NaN         NaN
# 1           NaN           NaN         NaN         NaN         NaN         NaN
# 2           NaN           NaN         NaN         NaN         NaN         NaN
# 3           NaN           NaN         NaN         NaN         NaN         NaN
# 4           NaN           NaN         NaN         NaN         NaN         NaN
#
#    S3_2_C5_16  S3_2_C6_14  S3_2_C6_16  S3_5_C1_17  S3_5_C1_5  S3_5_C1_7  \
# 0         NaN         NaN         NaN         NaN        NaN        NaN
# 1         NaN         NaN         NaN         NaN        NaN        NaN
# 2         NaN         NaN         NaN         NaN        NaN        NaN
# 3         NaN         NaN         NaN         NaN        NaN        NaN
# 4         NaN         NaN         NaN         NaN        NaN        NaN
#
#    S3_5_C2_12  S3_5_C2_7  S4_HHA2_C1_34  S4_HHA2_C2_34  S4_HHA2_C3_34  \
# 0         NaN        NaN            NaN            NaN            NaN
# 1         NaN        NaN            NaN            NaN            NaN
# 2         NaN        NaN            NaN            NaN            NaN
# 3         NaN        NaN            NaN            NaN            NaN
# 4         NaN        NaN            NaN            NaN            NaN
#
#    S4_HHA2_C4_34  S4_HHA2_C4_37  S4_HHA2_C4_38  S4_HHA2_C5_34  S4_HHA3_C1_33  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    S4_HHA3_C1_34  S4_HHA3_C1_35  S4_HHA3_C1_36  S4_HHA3_C1_38  S4_HHA3_C2_33  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    S4_HHA3_C2_34  S4_HHA3_C2_35  S4_HHA3_C2_37  S4_HHA3_C2_38  S4_HHA3_C3_33  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    S4_HHA3_C3_34  S4_HHA3_C3_35  S4_HHA3_C3_36  S4_HHA3_C3_38  S4_HHA3_C4_33  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    S4_HHA3_C4_34  S4_HHA3_C4_35  S4_HHA3_C4_36  S4_HHA3_C4_37  S4_HHA3_C4_38  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    S4_HHA3_C5_33  S4_HHA3_C5_34  S4_HHA3_C5_35  S4_HHA3_C5_36  S4_HHA3_C5_37  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    S4_HHA3_C5_38  S5_C1_13  S5_C1_14  S5_C1_15  S5_C2_10   A7_1_C1_1  \
# 0            NaN       NaN       NaN       NaN       NaN    800000.0
# 1            NaN       NaN       NaN       NaN       NaN  49497593.0
# 2            NaN       NaN       NaN       NaN       NaN         NaN
# 3            NaN       NaN       NaN       NaN       NaN         NaN
# 4            NaN       NaN       NaN       NaN       NaN         NaN
#
#      A7_1_C1_10    A7_1_C1_3    A7_1_C1_6     A7_1_C1_8  A7_1_C2_10  \
# 0  6.422161e+06    4239536.0    1382625.0  6.422161e+06     31945.0
# 1  1.414122e+09  871006111.0  301395768.0  1.414122e+09  12943382.0
# 2           NaN          NaN          NaN           NaN   1890565.0
# 3  1.337697e+06          NaN    1337697.0  1.337697e+06         NaN
# 4  7.154380e+05          NaN    1176343.0  1.176343e+06    318040.0
#
#    A7_1_C2_6   A7_1_C2_8  A7_3_C11_3  A7_3_C15_3   A7_3_C9_3    A8_C2_10  \
# 0    31945.0     31945.0     50942.0     94518.0     43576.0   -477513.0
# 1  9422788.0  12943382.0   1562888.0  28574972.0  20452110.0 -13475145.0
# 2  1400865.0   1890565.0         NaN    689879.0     41352.0     -3153.0
# 3        NaN         NaN         NaN    127817.0     66884.0    -19600.0
# 4   318040.0    318040.0         NaN     66840.0     58590.0    -11508.0
#
#    A8_C2_14  A8_C2_18    A8_C2_2  A8_C2_22    A8_C2_50  A8_C2_7  A8_C2_8  \
# 0   -6441.0   -1295.0    -3764.0  -21973.0   -540366.0   -152.0    -61.0
# 1       NaN       NaN -1471482.0       NaN -41508929.0      NaN      NaN
# 2       NaN       NaN        NaN       NaN    -47788.0      NaN      NaN
# 3   -2821.0       NaN        NaN       NaN   -282574.0      NaN      NaN
# 4       NaN       NaN        NaN       NaN    -55996.0      NaN      NaN
#
#       A_C1_200     A_C1_30  A_C2_113     A_C2_200     A_C2_30    A_C6_200  \
# 0    1586306.0    492514.0   76679.0    2530022.0     71685.0   -540366.0
# 1  195071447.0  28049485.0       NaN  258081827.0  10603662.0 -41508929.0
# 2     945859.0    297627.0       NaN    1932416.0    329802.0    -47788.0
# 3    2191053.0    324571.0   20283.0    2113183.0      4897.0   -282574.0
# 4    1687354.0    162161.0       NaN    1686150.0     30242.0    -55996.0
#
#      A_C6_30   B_1_C0_200   B_1_C0_30  B_1_C26_202  B_1_C26_30  B_2_C26_202  \
# 0   -86019.0    3575962.0    465683.0    3575962.0    972322.0      94518.0
# 1 -4520277.0  411644345.0  32202096.0  411644345.0  53090884.0   28574972.0
# 2    -9372.0    2830487.0    618057.0    2830487.0   1847904.0     689879.0
# 3        NaN    4021662.0    316742.0    4021662.0    671662.0     127817.0
# 4        NaN    3317508.0    192403.0    3317508.0    371258.0      66840.0
#
#    B_2_C26_30   C_1_C3_202   C_1_C6_200   C_1_C6_202    C_1_C6_30  \
# 0     37281.0    3464690.0    1741691.0    1741691.0     616464.0
# 1   5608716.0  213428573.0  665175242.0  665175242.0  134862756.0
# 2    509025.0    2739556.0    6108496.0    6108496.0    2897500.0
# 3     28645.0    4021516.0    2831881.0    2831881.0     318227.0
# 4     13276.0    3317508.0    1762804.0    1762804.0     203555.0
#
#     C_1_C7_200   C_1_C7_202    C_1_C8_202  D1_HOS_C1_26  D1_HOS_C1_27  \
# 0    7854241.0    7854241.0  9.595932e+06      524252.0      448070.0
# 1  523698958.0  523698958.0  1.188874e+09           NaN    53090884.0
# 2          NaN          NaN  6.108496e+06           NaN     1850385.0
# 3    3280908.0    3280908.0  6.112789e+06      525149.0      146513.0
# 4    6109909.0    6109909.0  7.872713e+06      216947.0      154311.0
#
#    D1_HOS_C1_37  D1_HOS_C1_41  D1_HOS_C1_48  D1_HOS_C1_49  D3_HOS_C2_200  \
# 0      448070.0      309327.0      147449.0      456776.0       364882.0
# 1    53090884.0    15179425.0    27973016.0    47716338.0    175458621.0
# 2     1850385.0     1222686.0      589246.0     1811932.0      2136171.0
# 3      146513.0       47016.0       39081.0       86097.0        57652.0
# 4      154311.0       39977.0       74312.0      114289.0       186367.0
#
#    D3_HOS_C2_202  D3_HOS_C2_30  D3_HOS_C3_200  D_2_HOS_C5_200  D_5_HOS_C3_200  \
# 0       364882.0      214744.0       147449.0          2057.0       1525396.0
# 1    175458621.0    44350333.0     27973016.0       1105570.0             NaN
# 2      2136171.0     1917100.0       589246.0        116441.0             NaN
# 3        57652.0       40850.0        39081.0           690.0        422522.0
# 4       186367.0       47500.0        74312.0           820.0        891091.0
#
#    D_5_HOS_C6_200  E2_SWSNF_C1_1  E2_SWSNF_C1_10  E2_SWSNF_C1_12  \
# 0        437145.0       521465.0        693616.0        693616.0
# 1             NaN            NaN             NaN             NaN
# 2             NaN            NaN             NaN             NaN
# 3        232460.0       331297.0        521800.0        521800.0
# 4        260170.0        71870.0        109208.0        109208.0
#
#    E2_SWSNF_C1_13  E2_SWSNF_C1_15  E2_SWSNF_C1_19  E2_SWSNF_C1_20  \
# 0          5280.0        688336.0        688336.0        568460.0
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3         18128.0        503672.0        503672.0        437470.0
# 4          2112.0        107096.0        107096.0        117470.0
#
#    E2_SWSNF_C1_22  E2_SWSNF_C1_3  E2_SWSNF_C1_5  E2_SWSNF_C1_8  E3_5_C1_1  \
# 0        119876.0       172151.0          227.0       693616.0   456776.0
# 1             NaN            NaN            NaN            NaN        NaN
# 2             NaN            NaN            NaN            NaN        NaN
# 3         66202.0       190503.0          300.0       521800.0    86097.0
# 4        -10374.0        37338.0           89.0       109208.0   114289.0
#
#    E3_5_C1_19  E3_5_C1_20  E3_5_C1_22  E3_5_C1_23  E3_5_C1_24  E3_5_C1_28  \
# 0    456776.0     33792.0    422984.0      1056.0    421928.0    421928.0
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3     86958.0     14080.0     72878.0         NaN     72878.0     72878.0
# 4    115432.0     11264.0    104168.0         NaN    104168.0    104168.0
#
#    E3_5_C1_30  E3_5_C1_31  E3_5_C1_33  E3_5_C1_4  E3_5_C1_6  E_B_HOS_C1_1  \
# 0    421928.0    377331.0     44597.0   456776.0   456776.0      437145.0
# 1         NaN         NaN         NaN        NaN        NaN       29926.0
# 2         NaN         NaN         NaN        NaN        NaN           NaN
# 3     72878.0    183809.0   -110931.0    86097.0    86958.0      232460.0
# 4    104168.0     95189.0      8979.0   114289.0   115432.0      260170.0
#
#    E_B_HOS_C1_11  E_B_HOS_C1_21  E_B_HOS_C1_25  E_B_HOS_C1_26  E_B_HOS_C1_27  \
# 0       437145.0       441516.0         1479.0       235966.0       204071.0
# 1        29926.0        29926.0            NaN      2817435.0     14007771.0
# 2            NaN            NaN            NaN            NaN            NaN
# 3       232460.0       234785.0            NaN        78083.0       156702.0
# 4       260170.0       262772.0          583.0       127721.0       134468.0
#
#    E_B_HOS_C1_30  E_B_HOS_C1_32  E_B_HOS_C1_37  E_B_HOS_C1_40  E_B_HOS_C1_41  \
# 0       204071.0       204071.0       204071.0       204071.0       205442.0
# 1     14007771.0     14006520.0     14047252.0     14047252.0     14113965.0
# 2            NaN            NaN            NaN            NaN            NaN
# 3       156702.0       156702.0       156702.0       156702.0       120500.0
# 4       134468.0       134468.0       134468.0       134468.0       186841.0
#
#    E_B_HOS_C1_43      G2_C1_1     G2_C1_10     G2_C1_17     G2_C1_18  \
# 0        -1371.0     616464.0     616464.0     616464.0     973649.0
# 1       -66713.0  264220720.0  264220720.0  282108543.0  429594158.0
# 2            NaN    2897500.0    2897500.0    2897500.0    3210996.0
# 3        36202.0     318227.0    1885423.0    1885423.0     934562.0
# 4       -52373.0     380943.0    1165102.0    1165102.0     767452.0
#
#      G2_C1_19     G2_C1_28     G2_C2_18    G2_C2_19     G2_C2_28     G2_C2_43  \
# 0     23434.0    1613547.0    5716903.0   2712582.0    8493215.0    4116328.0
# 1  29443542.0  741457190.0  461798083.0  95784275.0  945765536.0  453153274.0
# 2         NaN    6108496.0          NaN         NaN          NaN    2878275.0
# 3     11896.0    2831881.0    1415535.0    969250.0    3477293.0    4304236.0
# 4         NaN    1932554.0    3612422.0   1642337.0    6203976.0    3373504.0
#
#         G3_C1_1  G3_C1_14  G3_C1_18       G3_C1_2  G3_C1_2450   G3_C1_25  \
# 0  1.010676e+07    6441.0    1295.0  6.763939e+06    271338.0   301956.0
# 1  1.687223e+09       NaN       NaN  1.246301e+09         NaN  9982013.0
# 2  6.108496e+06       NaN       NaN  3.692254e+06     16897.0    16900.0
# 3  6.309174e+06    2821.0       NaN  4.591086e+06    240108.0   618035.0
# 4  8.136530e+06    3520.0       NaN  8.796475e+06         NaN   234601.0
#
#     G3_C1_26   G3_C1_29      G3_C1_3      G3_C1_4     G3_C1_5    G3_C1_7  \
# 0  -471549.0  -471549.0    3342823.0    4116328.0   -773505.0     3764.0
# 1 -2249293.0 -2249293.0  440921968.0  453153274.0 -12231306.0  2587053.0
# 2  -445133.0  -445133.0    2416242.0    2878275.0   -462033.0        NaN
# 3 -1968113.0 -2607321.0    1718088.0    4304236.0  -2586148.0      106.0
# 4 -3798848.0 -4485126.0    -659945.0    3373504.0  -4033449.0        NaN
#
#    S10_C1_1    S10_C1_2   S10_C1_20  S10_C1_21  S10_C1_23   S10_C1_30  \
# 0  0.361058    479217.0     11202.0     4045.0     4045.0      4045.0
# 1  0.179522  13212758.0  35540531.0  6380307.0  6380307.0  17727348.0
# 2       NaN         NaN         NaN        NaN        NaN         NaN
# 3  0.657886    339308.0         NaN        NaN        NaN    420526.0
# 4  0.421393    231778.0      1524.0      642.0      642.0    313043.0
#
#     S10_C1_31     S10_C1_6    S10_C1_7   S10_C3_20   S10_C3_21   S10_C3_23  \
# 0      4045.0    1064927.0    384500.0     11202.0      4045.0      4045.0
# 1  20846802.0  101626841.0  18244254.0  42906543.0  13746319.0  13746319.0
# 2         NaN          NaN         NaN         NaN         NaN         NaN
# 3    741311.0    1573363.0   1035093.0         NaN         NaN         NaN
# 4    870990.0    1874083.0    789725.0     24732.0     23850.0     23850.0
#
#    S2_1_C1_26  S2_1_C1_27  S2_1_C4_3  S3_1_C10_14  S3_1_C10_27  S3_1_C13_1  \
# 0         2.0         2.0        1.0        52.21        52.21        35.0
# 1         1.0         1.0        1.0      5673.00      5673.00      2716.0
# 2         1.0         1.0        5.0        43.95        43.95        89.0
# 3         2.0         2.0        1.0       143.25       235.25        14.0
# 4         1.0         1.0        1.0        98.40       143.70        13.0
#
#    S3_1_C13_14  S3_1_C13_2  S3_1_C15_1  S3_1_C15_14  S3_1_C2_1  S3_1_C2_14  \
# 0         35.0         3.0        38.0         38.0       25.0        25.0
# 1       2716.0      1254.0      8897.0       8897.0      450.0       497.0
# 2         89.0         3.0       119.0        119.0       42.0        42.0
# 3         14.0         3.0        32.0         32.0       25.0        25.0
# 4         13.0        15.0        37.0         37.0       25.0        25.0
#
#    S3_1_C2_27  S3_1_C2_7  S3_1_C3_1  S3_1_C3_14  S3_1_C3_7  S3_1_C4_1  \
# 0        25.0       25.0     2300.0      2300.0     2300.0     3264.0
# 1       497.0      450.0    55350.0     61131.0    55350.0        NaN
# 2        42.0       42.0     3864.0      3864.0     3864.0        NaN
# 3       152.0       25.0     2300.0      2300.0     2300.0     2712.0
# 4        65.0       25.0     2300.0      2300.0     2300.0     3312.0
#
#    S3_1_C4_14  S3_1_C4_7  S3_1_C6_1  S3_1_C6_14  S3_1_C6_2  S3_1_C6_5  \
# 0      3264.0     3264.0      136.0       363.0       13.0      227.0
# 1         NaN        NaN    15546.0     17662.0     8677.0        NaN
# 2         NaN        NaN     1009.0      1009.0       54.0        NaN
# 3      2712.0     2712.0       43.0       343.0        8.0      300.0
# 4      3312.0     3312.0       50.0       139.0       44.0       89.0
#
#    S3_1_C6_7  S3_1_C7_28  S3_1_C8_1  S3_1_C8_14  S3_1_C8_28  S3_1_C8_5  \
# 0      363.0         3.0      164.0       444.0        33.0      227.0
# 1    15546.0        65.0    43680.0     51011.0     10693.0        NaN
# 2     1009.0         NaN     1527.0      1527.0         NaN        NaN
# 3      343.0         NaN       96.0       588.0        38.0      478.0
# 4      139.0         NaN      138.0       414.0        55.0      270.0
#
#    S3_1_C8_6  S3_1_C8_7   A7_1_C1_2  A7_1_C1_4  A7_1_C1_5    A7_1_C1_7  \
# ...
# 3            NaN         NaN         NaN           NaN           NaN
# 4            NaN         NaN         NaN           NaN           NaN
#
#    D_4_SNF_C11_54  G_C1THRU4_58  D3_SNF_C2_70  D3_SNF_C3_70  D_5_HOS_C4_56  \
# 0             NaN           NaN           NaN           NaN            NaN
# 1             NaN           NaN           NaN           NaN            NaN
# 2             NaN           NaN           NaN           NaN            NaN
# 3             NaN           NaN           NaN           NaN            NaN
# 4             NaN           NaN           NaN           NaN            NaN
#
#    D_5_HOS_C7_56  E3_1_HOS_C1_17  A_C1_12  A_C6_12  A_C1_89  A_C2_89  A_C6_89  \
# 0            NaN             NaN      NaN      NaN      NaN      NaN      NaN
# 1            NaN             NaN      NaN      NaN      NaN      NaN      NaN
# 2            NaN             NaN      NaN      NaN      NaN      NaN      NaN
# 3            NaN             NaN      NaN      NaN      NaN      NaN      NaN
# 4            NaN             NaN      NaN      NaN      NaN      NaN      NaN
#
#    B_1_C0_89  B_1_C26_89  B_2_C26_89  C_1_C5_89  C_1_C7_89  G2_C2_21  \
# 0        NaN         NaN         NaN        NaN        NaN       NaN
# 1        NaN         NaN         NaN        NaN        NaN       NaN
# 2        NaN         NaN         NaN        NaN        NaN       NaN
# 3        NaN         NaN         NaN        NaN        NaN       NaN
# 4        NaN         NaN         NaN        NaN        NaN       NaN
#
#    G_C1THRU4_56  D_3_HOS_C9_33  D_4_HOS_C2_90  D_4_IPF_C11_55  D_4_IPF_C11_76  \
# 0           NaN            NaN            NaN             NaN             NaN
# 1           NaN            NaN            NaN             NaN             NaN
# 2           NaN            NaN            NaN             NaN             NaN
# 3           NaN            NaN            NaN             NaN             NaN
# 4           NaN            NaN            NaN             NaN             NaN
#
#    D_4_IPF_C13_76  D_5_HOS_C3_9201  D_5_HOS_C4_53  D_5_HOS_C4_70  \
# 0             NaN              NaN            NaN            NaN
# 1             NaN              NaN            NaN            NaN
# 2             NaN              NaN            NaN            NaN
# 3             NaN              NaN            NaN            NaN
# 4             NaN              NaN            NaN            NaN
#
#    D_5_HOS_C7_53  D_4_IPF_C13_54  D_4_HOS_C2_54  D_4_HOS_C2_59  \
# 0            NaN             NaN            NaN            NaN
# 1            NaN             NaN            NaN            NaN
# 2            NaN             NaN            NaN            NaN
# 3            NaN             NaN            NaN            NaN
# 4            NaN             NaN            NaN            NaN
#
#    D_4_IPF_C13_91  D_4_IRF_C11_76  D_4_IRF_C13_76  D_5_HOS_C4_52  \
# 0             NaN             NaN             NaN            NaN
# 1             NaN             NaN             NaN            NaN
# 2             NaN             NaN             NaN            NaN
# 3             NaN             NaN             NaN            NaN
# 4             NaN             NaN             NaN            NaN
#
#    D_5_HOS_C4_67  D_5_HOS_C4_68  D_5_HOS_C7_52  D_5_HOS_C7_67  D_5_HOS_C7_68  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    D_5_HOS_C7_70  D_4_HOS_C2_65  D_4_HOS_C2_93  D_4_SNF_C11_50  \
# 0            NaN            NaN            NaN             NaN
# 1            NaN            NaN            NaN             NaN
# 2            NaN            NaN            NaN             NaN
# 3            NaN            NaN            NaN             NaN
# 4            NaN            NaN            NaN             NaN
#
#    D_4_SNF_C11_60  D_4_SNF_C11_65  B_1_C21_33  B_1_C21_62  B_1_C21_71  \
# 0             NaN             NaN         NaN         NaN         NaN
# 1             NaN             NaN         NaN         NaN         NaN
# 2             NaN             NaN         NaN         NaN         NaN
# 3             NaN             NaN         NaN         NaN         NaN
# 4             NaN             NaN         NaN         NaN         NaN
#
#    B_1_C21_72  B_1_C21_9201  B_1_C22_33  B_1_C22_62  B_1_C22_71  B_1_C22_72  \
# 0         NaN           NaN         NaN         NaN         NaN         NaN
# 1         NaN           NaN         NaN         NaN         NaN         NaN
# 2         NaN           NaN         NaN         NaN         NaN         NaN
# 3         NaN           NaN         NaN         NaN         NaN         NaN
# 4         NaN           NaN         NaN         NaN         NaN         NaN
#
#    B_1_C22_9201  D1_HOS_C5_45  C_1_C7_117  A_C1_72  A_C1_115  A_C2_115  \
# 0           NaN           NaN         NaN      NaN       NaN       NaN
# 1           NaN           NaN         NaN      NaN       NaN       NaN
# 2           NaN           NaN         NaN      NaN       NaN       NaN
# 3           NaN           NaN         NaN      NaN       NaN       NaN
# 4           NaN           NaN         NaN      NaN       NaN       NaN
#
#    B_1_C0_115  B_1_C26_115  B_2_C26_115  C_1_C5_115  C_1_C7_115  \
# 0         NaN          NaN          NaN         NaN         NaN
# 1         NaN          NaN          NaN         NaN         NaN
# 2         NaN          NaN          NaN         NaN         NaN
# 3         NaN          NaN          NaN         NaN         NaN
# 4         NaN          NaN          NaN         NaN         NaN
#
#    D_4_HOS_C2_64  D_4_HOS_C2_76  D_4_HOS_C2_9201  G_C1THRU4_55  D3_SNF_C2_75  \
# 0            NaN            NaN              NaN           NaN           NaN
# 1            NaN            NaN              NaN           NaN           NaN
# 2            NaN            NaN              NaN           NaN           NaN
# 3            NaN            NaN              NaN           NaN           NaN
# 4            NaN            NaN              NaN           NaN           NaN
#
#    D3_SNF_C3_75  D_4_HOS_C2_57  D_4_HOS_C2_58  D_4_HOS_C2_60  D_4_HOS_C2_69  \
# 0           NaN            NaN            NaN            NaN            NaN
# 1           NaN            NaN            NaN            NaN            NaN
# 2           NaN            NaN            NaN            NaN            NaN
# 3           NaN            NaN            NaN            NaN            NaN
# 4           NaN            NaN            NaN            NaN            NaN
#
#    D_4_IPF_C13_57  D_4_HOS_C1_50  E3_2_IPF_C1_30  D_4_HOS_C1_76  B_1_C21_64  \
# 0             NaN            NaN             NaN            NaN         NaN
# 1             NaN            NaN             NaN            NaN         NaN
# 2             NaN            NaN             NaN            NaN         NaN
# 3             NaN            NaN             NaN            NaN         NaN
# 4             NaN            NaN             NaN            NaN         NaN
#
#    B_1_C22_64  D_4_IRF_C13_69  D_4_HOS_C4_50  D_4_HOS_C4_91  D_4_HOS_C2_75  \
# 0         NaN             NaN            NaN            NaN            NaN
# 1         NaN             NaN            NaN            NaN            NaN
# 2         NaN             NaN            NaN            NaN            NaN
# 3         NaN             NaN            NaN            NaN            NaN
# 4         NaN             NaN            NaN            NaN            NaN
#
#    D_4_IPF_C11_59  D_4_IRF_C11_59  D_4_IRF_C11_90  S3_1_C5_26  D_4_HOS_C4_54  \
# 0             NaN             NaN             NaN         NaN            NaN
# 1             NaN             NaN             NaN         NaN            NaN
# 2             NaN             NaN             NaN         NaN            NaN
# 3             NaN             NaN             NaN         NaN            NaN
# 4             NaN             NaN             NaN         NaN            NaN
#
#    D_4_HOS_C4_69  B_1_C26_99  B_2_C26_99  C_1_C5_99  C_1_C6_99  C_1_C7_99  \
# 0            NaN         NaN         NaN        NaN        NaN        NaN
# 1            NaN         NaN         NaN        NaN        NaN        NaN
# 2            NaN         NaN         NaN        NaN        NaN        NaN
# 3            NaN         NaN         NaN        NaN        NaN        NaN
# 4            NaN         NaN         NaN        NaN        NaN        NaN
#
#    C_1_C2_67  D_4_IRF_C13_60  B_1_C21_88  B_1_C22_88  S3_1_C9_26  \
# 0        NaN             NaN         NaN         NaN         NaN
# 1        NaN             NaN         NaN         NaN         NaN
# 2        NaN             NaN         NaN         NaN         NaN
# 3        NaN             NaN         NaN         NaN         NaN
# 4        NaN             NaN         NaN         NaN         NaN
#
#    D_4_HOS_C4_52  D_4_HOS_C4_76  D_4_HOS_C4_90  C_1_C6_115  C_1_C6_96  \
# 0            NaN            NaN            NaN         NaN        NaN
# 1            NaN            NaN            NaN         NaN        NaN
# 2            NaN            NaN            NaN         NaN        NaN
# 3            NaN            NaN            NaN         NaN        NaN
# 4            NaN            NaN            NaN         NaN        NaN
#
#    D_4_IPF_C13_60  D_4_HOS_C2_55  D_4_SNF_C11_55  C_1_C6_117  S3_1_C11_26  \
# 0             NaN            NaN             NaN         NaN          NaN
# 1             NaN            NaN             NaN         NaN          NaN
# 2             NaN            NaN             NaN         NaN          NaN
# 3             NaN            NaN             NaN         NaN          NaN
# 4             NaN            NaN             NaN         NaN          NaN
#
#    D_4_IPF_C13_58  D_4_IRF_C13_57  D_4_IPF_C11_63  D_4_IRF_C11_63  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    D_4_IPF_C11_9201  B_1_C0_6250  B_1_C26_6250  B_2_C26_6250  C_1_C5_6250  \
# 0               NaN          NaN           NaN           NaN          NaN
# 1               NaN          NaN           NaN           NaN          NaN
# 2               NaN          NaN           NaN           NaN          NaN
# 3               NaN          NaN           NaN           NaN          NaN
# 4               NaN          NaN           NaN           NaN          NaN
#
#    C_1_C6_6250  C_1_C7_6250  E_B_IPF_C1_39  D_4_HOS_C4_66  D_4_IPF_C13_69  \
# 0          NaN          NaN            NaN            NaN             NaN
# 1          NaN          NaN            NaN            NaN             NaN
# 2          NaN          NaN            NaN            NaN             NaN
# 3          NaN          NaN            NaN            NaN             NaN
# 4          NaN          NaN            NaN            NaN             NaN
#
#    D_5_HOS_C6_9201  S3_1_C5_12  D_4_IRF_C13_91  D_4_HOS_C2_67  D_4_IRF_C11_70  \
# 0              NaN         NaN             NaN            NaN             NaN
# 1              NaN         NaN             NaN            NaN             NaN
# 2              NaN         NaN             NaN            NaN             NaN
# 3              NaN         NaN             NaN            NaN             NaN
# 4              NaN         NaN             NaN            NaN             NaN
#
#    S3_1_C4_11  G2_C1_24  D_4_HOS_C4_93  D_4_SNF_C11_66  D_4_IPF_C11_52  \
# 0         NaN       NaN            NaN             NaN             NaN
# 1         NaN       NaN            NaN             NaN             NaN
# 2         NaN       NaN            NaN             NaN             NaN
# 3         NaN       NaN            NaN             NaN             NaN
# 4         NaN       NaN            NaN             NaN             NaN
#
#    B_1_C21_101  B_1_C22_101  S3_1_C4_10  S3_1_C9_22  D_4_SNF_C11_69  \
# 0          NaN          NaN         NaN         NaN             NaN
# 1          NaN          NaN         NaN         NaN             NaN
# 2          NaN          NaN         NaN         NaN             NaN
# 3          NaN          NaN         NaN         NaN             NaN
# 4          NaN          NaN         NaN         NaN             NaN
#
#    D_4_SNF_C11_90  D_4_SNF_C11_91  D_4_HOS_C4_53  B_1_C21_112  B_1_C22_112  \
# 0             NaN             NaN            NaN          NaN          NaN
# 1             NaN             NaN            NaN          NaN          NaN
# 2             NaN             NaN            NaN          NaN          NaN
# 3             NaN             NaN            NaN          NaN          NaN
# 4             NaN             NaN            NaN          NaN          NaN
#
#    D3_HOS_C2_96  D3_HOS_C3_96  D_2_HOS_C5_96  D_4_HOS_C10_96  D_5_HOS_C3_96  \
# 0           NaN           NaN            NaN             NaN            NaN
# 1           NaN           NaN            NaN             NaN            NaN
# 2           NaN           NaN            NaN             NaN            NaN
# 3           NaN           NaN            NaN             NaN            NaN
# 4           NaN           NaN            NaN             NaN            NaN
#
#    D_5_HOS_C6_96  D_4_IPF_C11_93  D_4_HOS_C11_62  D_4_HOS_C13_62  \
# 0            NaN             NaN             NaN             NaN
# 1            NaN             NaN             NaN             NaN
# 2            NaN             NaN             NaN             NaN
# 3            NaN             NaN             NaN             NaN
# 4            NaN             NaN             NaN             NaN
#
#    D_4_HOS_C3_62  D_4_IRF_C11_62  E3_2_HOS_C1_30  A_C1_9910  A_C2_9910  \
# 0            NaN             NaN             NaN        NaN        NaN
# 1            NaN             NaN             NaN        NaN        NaN
# 2            NaN             NaN             NaN        NaN        NaN
# 3            NaN             NaN             NaN        NaN        NaN
# 4            NaN             NaN             NaN        NaN        NaN
#
#    D_4_IPF_C11_70  D_5_HOS_C4_62  D_5_HOS_C7_62  D_4_HOS_C4_55  D_4_HOS_C4_65  \
# 0             NaN            NaN            NaN            NaN            NaN
# 1             NaN            NaN            NaN            NaN            NaN
# 2             NaN            NaN            NaN            NaN            NaN
# 3             NaN            NaN            NaN            NaN            NaN
# 4             NaN            NaN            NaN            NaN            NaN
#
#    B_1_C21_89  C_1_C6_89  G2_C1_21  D_4_HOS_C4_88  D_4_HOS_C4_60  \
# 0         NaN        NaN       NaN            NaN            NaN
# 1         NaN        NaN       NaN            NaN            NaN
# 2         NaN        NaN       NaN            NaN            NaN
# 3         NaN        NaN       NaN            NaN            NaN
# 4         NaN        NaN       NaN            NaN            NaN
#
#    D_4_HOS_C4_67  D_4_HOS_C4_68  D_4_HOS_C4_71  D_4_HOS_C4_73  D_4_SNF_C11_75  \
# 0            NaN            NaN            NaN            NaN             NaN
# 1            NaN            NaN            NaN            NaN             NaN
# 2            NaN            NaN            NaN            NaN             NaN
# 3            NaN            NaN            NaN            NaN             NaN
# 4            NaN            NaN            NaN            NaN             NaN
#
#   File Date
# 0      2021
# 1      2021
# 2      2021
# 3      2021
# 4      2021

# %%
c1 = list(main_df)
c2 = []
for c in c1:
    if 'E3_2_HOS_C1_1' in c:
        c2.append(c)
        
rush_df = main_df[main_df['prvdr_num'] == '140119']
rush_df = rush_df.filter(items=['prvdr_num', 'fy_bgn_dt', 'fy_end_dt'] + c2)
#rush_df = rush_df[rush_df['fy_bgn_dt'].isin(['2019-07-01', '2020-07-01'])]
rush_df.head(40)
# Out:
#       prvdr_num  fy_bgn_dt  fy_end_dt  E3_2_HOS_C1_13  E3_2_HOS_C1_1  \
# 6943     140119 2020-07-01 2021-06-30             NaN            NaN
# 11833    140119 2019-07-01 2020-06-30             NaN            NaN
# 17944    140119 2018-07-01 2019-06-30             NaN            NaN
# 22568    140119 2017-07-01 2018-06-30             NaN            NaN
# 28431    140119 2016-07-01 2017-06-30             NaN            NaN
# 39526    140119 2015-07-01 2016-06-30             NaN            NaN
# 45272    140119 2014-07-01 2015-06-30             NaN            NaN
# 51971    140119 2013-07-01 2014-06-30             NaN            NaN
# 58233    140119 2012-07-01 2013-06-30             NaN            NaN
# 64397    140119 2011-07-01 2012-06-30             NaN            NaN
# 66577    140119 2010-07-01 2011-06-30             NaN            NaN
#
#        E3_2_HOS_C1_12  E3_2_HOS_C1_16  E3_2_HOS_C1_18  E3_2_HOS_C1_19  \
# 6943              NaN             NaN             NaN             NaN
# 11833             NaN             NaN             NaN             NaN
# 17944             NaN             NaN             NaN             NaN
# 22568             NaN             NaN             NaN             NaN
# 28431             NaN             NaN             NaN             NaN
# 39526             NaN             NaN             NaN             NaN
# 45272             NaN             NaN             NaN             NaN
# 51971             NaN             NaN             NaN             NaN
# 58233             NaN             NaN             NaN             NaN
# 64397             NaN             NaN             NaN             NaN
# 66577             NaN             NaN             NaN             NaN
#
#        E3_2_HOS_C1_17  E3_2_HOS_C1_10  E3_2_HOS_C1_11  E3_2_HOS_C1_15
# 6943              NaN             NaN             NaN             NaN
# 11833             NaN             NaN             NaN             NaN
# 17944             NaN             NaN             NaN             NaN
# 22568             NaN             NaN             NaN             NaN
# 28431             NaN             NaN             NaN             NaN
# 39526             NaN             NaN             NaN             NaN
# 45272             NaN             NaN             NaN             NaN
# 51971             NaN             NaN             NaN             NaN
# 58233             NaN             NaN             NaN             NaN
# 64397             NaN             NaN             NaN             NaN
# 66577             NaN             NaN             NaN             NaN

# %%
c1 = list(main_df)
c2 = []
for c in c1:
    if 'S10_C1_23' in c:
        c2.append(c)
        
rush_df = main_df[main_df['prvdr_num'] == '140119']
rush_df = rush_df.filter(items=['prvdr_num', 'fy_bgn_dt', 'fy_end_dt'] + c2)
#rush_df = rush_df[rush_df['fy_bgn_dt'].isin(['2019-07-01', '2020-07-01'])]
rush_df.head(40)
# Out:
#       prvdr_num  fy_bgn_dt  fy_end_dt   S10_C1_23
# 6943     140119 2020-07-01 2021-06-30  15369741.0
# 11833    140119 2019-07-01 2020-06-30  24305273.0
# 17944    140119 2018-07-01 2019-06-30  17170606.0
# 22568    140119 2017-07-01 2018-06-30  18034612.0
# 28431    140119 2016-07-01 2017-06-30  18114216.0
# 39526    140119 2015-07-01 2016-06-30  17480905.0
# 45272    140119 2014-07-01 2015-06-30  18690451.0
# 51971    140119 2013-07-01 2014-06-30  26256715.0
# 58233    140119 2012-07-01 2013-06-30  26276785.0
# 64397    140119 2011-07-01 2012-06-30  21321897.0
# 66577    140119 2010-07-01 2011-06-30  13525003.0

# %%
rush_df = main_df[main_df['prvdr_num'] == '140119']
print('rush_df.shape:', rush_df.shape)
rush_df.to_excel('all_data/rush_hcris.xlsx', engine='xlsxwriter')

# %%
to_replace = ['rpt_rec_num', 'prvdr_num', 'fi_num', 'rpt_stus_cd', 'fi_creat_dt', 
              'fy_bgn_dt', 'fy_end_dt', 'util_cd', 'trnsmtl_num', 'state', 
              'st_cty_cd', 'census', 'region', 'proc_dt', 'msa']

replacement = ['RPT_REC_NUM', 'PRVDR_NUM', 'FI_NUM', 'RPT_STUS_CD', 'FI_CREAT_DT', 
               'FY_BGN_DT', 'FY_END_DT', 'UTIL_CODE', 'TRNSMTL_NUM', 'STATE', 
               'ST_CTY_CD', 'CENSUS', 'REGION', 'PROC_DT', 'MSA']

main_df.rename(columns = {to_replace[0]: replacement[0], to_replace[1]: replacement[1],
                           to_replace[2]: replacement[2], to_replace[3]: replacement[3],
                           to_replace[4]: replacement[4], to_replace[5]: replacement[5],
                           to_replace[6]: replacement[6], to_replace[7]: replacement[7],
                           to_replace[8]: replacement[8], to_replace[9]: replacement[9],
                           to_replace[10]: replacement[10], to_replace[11]: replacement[11],
                           to_replace[12]: replacement[12], to_replace[13]: replacement[13],
                           to_replace[14]: replacement[14] }, inplace = True)

main_df.drop(['_NAME_'], axis=1, inplace=True)

# %%
crosswalk_df = pd.read_csv('~/GitHub/HCRIS-databuilder/crosswalk/2552-10_SAS_FILE_RECORD_LAYOUT_AND_CROSSWALK_TO_96.csv', sep=',')
crosswalk_labels = crosswalk_df['10_FIELD_NAME'].tolist()
crosswalk_labels = [str(x).strip(' ') for x in crosswalk_labels]
crosswalk_df['10_FIELD_NAME'] = crosswalk_labels

# %%
main_df_col_labels = list(main_df)
main_df_col_labels = [str(x).strip(' ') for x in main_df_col_labels]
print('main_df with NaN columns removed: (rows, columns) =', main_df.shape)

print('\nNumber of labels in the crosswalk:', len(crosswalk_labels))
print('Number of unique labels in the crosswalk:', len(list(set(crosswalk_labels))))

print('\nNumber of labels in the main_df:', len(main_df_col_labels))
print('Number of unique labels in the main_df:', len(list(set(main_df_col_labels))))

shared_labels = list(set(main_df_col_labels) & set(crosswalk_labels))
print('\nNumber of labels shared between the main dataframe and the crosswalk:', len(shared_labels))
shared_labels.append('File Date')
print(shared_labels[-8:])

# %%
main_df2 = main_df[main_df.columns[main_df.columns.isin(shared_labels)]]

CODE = []
FIELD_DESCRIPTION = []
TYPE = []
SUBTYPE = []
#DATA_TYPE = []

col_labels = list(main_df2)
for lab in col_labels:
    if lab == 'File Date':
        CODE.append('File Date')
        FIELD_DESCRIPTION.append('File Date')
        TYPE.append('File Date')
        SUBTYPE.append('File Date')
    else:
        df_sub = crosswalk_df[crosswalk_df['10_FIELD_NAME'] == lab]
        CODE.append(df_sub['10_FIELD_NAME'].iloc[0])
        FIELD_DESCRIPTION.append(df_sub['FIELD DESCRIPTION '].iloc[0])
        TYPE.append(df_sub['TYPE'].iloc[0])
        SUBTYPE.append(df_sub['SUBTYPE'].iloc[0])
        #DATA_TYPE.append(df_sub['DATA_TYPE'].iloc[0])

SUBTYPE = pd.Series(SUBTYPE).fillna('').tolist()
TYPE = pd.Series(TYPE).fillna('').tolist()

for i, val in enumerate(SUBTYPE):
    if val == 'File Date':
        continue
    elif val == '':
        SUBTYPE[i] = str(FIELD_DESCRIPTION[i]) + ' ' + '(' + str(CODE[i]) + ')'
    else:
        SUBTYPE[i] = str(val) + ' ' + str(FIELD_DESCRIPTION[i]) + ' (' + str(CODE[i]) + ')'

df2 = pd.DataFrame([col_labels, FIELD_DESCRIPTION, TYPE, SUBTYPE], columns=col_labels)
main_df2 = pd.concat([df2, main_df2])

main_df2.head()

# %%
main_df2.columns=pd.MultiIndex.from_arrays(main_df2.iloc[0:4].values)
main_df2 = main_df2.iloc[4:]

main_df3 = main_df2.loc[:, ~main_df2.columns.get_level_values(1).isin({float('NaN')})]
print(main_df3.shape)
main_df3.head(10)

# %%
main_df4 = main_df3.copy(deep=True)
print(main_df4.shape)
main_df4 = main_df4[main_df4.columns.drop(list(main_df4.filter(regex='(Y/N)')))]
main_df4 = main_df4[main_df4.columns.drop(list(main_df4.filter(regex='costs?')))]
main_df4 = main_df4[main_df4.columns.drop(list(main_df4.filter(regex='NOT IN THIS FILE')))]
main_df4 = main_df4[main_df4.columns.drop(list(main_df4.filter(regex='Report Status Code')))]
main_df4 = main_df4[main_df4.columns.drop(list(main_df4.filter(regex='Urban/Rural Indicator at beginning')))]
#main_df4 = main_df4.dropna(axis=1, thresh=25000)
print(main_df4.shape)

# %%
CMS_Gen_Info_df = pd.read_csv('~/GitHub/HCRIS-databuilder/GeoData/Hospital_General_Information.tsv', sep='\t')
print(list(CMS_Gen_Info_df))
CMS_Gen_Info_df.head(10)

# %%
hospital_ls = main_df4.iloc[:, (main_df4.columns.get_level_values(0) == 'S2_1_C1_3')].T.values.tolist()[0]
id_ls = main_df4.iloc[:, (main_df4.columns.get_level_values(0) == 'PRVDR_NUM')].T.values.tolist()[0]

print(hospital_ls[0:4])
print(id_ls[0:4])

# %%
lats = []
lons = []
Htypes = []
Ctypes = []

misses = 0
hits = 0
for i, h in enumerate(hospital_ls):
    
    #if i > 100: break   
    fid = id_ls[i]
    
    try:
        df = CMS_Gen_Info_df[CMS_Gen_Info_df['Facility ID'] == fid]
            
        loc = df['Location'].iloc[0]
        loc = loc.replace("POINT (","") 
        loc = loc.replace(")","")
        loc = loc.split(" ")
            
        lat = loc[1]
        lon = loc[0]
        lats.append(lat)
        lons.append(lon)
        
        htype = df['Hospital Type'].iloc[0]
        Htypes.append(htype)
        ctype = df['Hospital Ownership'].iloc[0]
        Ctypes.append(ctype)
        
        #hits += 1
        
    except:
        #misses += 1
        lats.append(float('NaN'))
        lons.append(float('NaN'))
        Htypes.append(float('NaN'))
        Ctypes.append(float('NaN'))

# %%
main_df4[('Lat', 'Lat', 'Lat', 'Lat')] = lats
main_df4[('Lon', 'Lon', 'Lon', 'Lon')] = lons
main_df4[('Control type, text', 'Control type, text', 'Control type, text', 'Control type, text')] = Ctypes
main_df4[('Hospital type, text', 'Hospital type, text', 'Hospital type, text', 'Hospital type, text')] = Htypes
main_df4[('Num and Name', 'Num and Name', 'Num and Name', 'Num and Name')] = main_df4[('S2_1_C1_3', 'Hospital Name ', '', 'Hospital Name  (S2_1_C1_3)')] +' (' + main_df4[('PRVDR_NUM', 'Hospital Provider Number ', 'HOSPITAL IDENTIFICATION INFORMATION', 'Hospital Provider Number  (PRVDR_NUM)')] + ')'

# %%
badnames = ['20994', float('NaN'), '-0007', '1', '330354', '4499 ACUSHNET AVENUE OPERATING COMPA',
           '4499 ACUSHNET AVENUE OPERATING COMPM']

main_df4 = main_df4[~main_df4[('S2_1_C1_3', 'Hospital Name ', '', 'Hospital Name  (S2_1_C1_3)')].isin(badnames)]

# %%
main_df5 = main_df4.copy(deep=True)
print(main_df5.shape[1])
main_df5.dropna(axis=1, thresh = int(0.5*main_df5.shape[0]), inplace=True)
print(main_df5.shape[1])

# %%
tdf = main_df4.filter(items=[('Lat', 'Lat', 'Lat', 'Lat'),
                             ('Lon', 'Lon', 'Lon', 'Lon'),
                             ('Control type, text', 'Control type, text', 'Control type, text', 'Control type, text'),
                             ('Hospital type, text', 'Hospital type, text', 'Hospital type, text', 'Hospital type, text'),
                             ('Num and Name', 'Num and Name', 'Num and Name', 'Num and Name'),
                             ('S3_1_C2_27', 'Total Facility', 'NUMBER OF BEDS', 'Total Facility (S3_1_C2_27)'),
                             ('S2_1_C2_2', 'Hospital State', '', 'Hospital State (S2_1_C2_2)'),
                            ], axis=1)

tdf.to_pickle('GenDat4App/GenDat4App.pkl', protocol=4)

# %%
main_df4[('FY_END_DT', 'Fiscal Year End Date ', 'HOSPITAL IDENTIFICATION INFORMATION', 'Fiscal Year End Date  (FY_END_DT)')] = pd.to_datetime(main_df4[('FY_END_DT', 'Fiscal Year End Date ', 'HOSPITAL IDENTIFICATION INFORMATION', 'Fiscal Year End Date  (FY_END_DT)')])
main_df4.sort_values(by=[('Num and Name', 'Num and Name', 'Num and Name', 'Num and Name'),
                     ('FY_END_DT', 'Fiscal Year End Date ', 'HOSPITAL IDENTIFICATION INFORMATION', 'Fiscal Year End Date  (FY_END_DT)')],
                     ascending=[True, True])

# %%
import re

numNname = sorted(list(set(main_df4[('Num and Name', 'Num and Name', 'Num and Name', 'Num and Name')].tolist())))

for i, val in enumerate(numNname):
    prvdr = re.sub('\ |\?|\.|\!|\/|\;|\:', '', val)

    tdf = main_df4[main_df4[('Num and Name', 'Num and Name', 'Num and Name', 'Num and Name')] == val]
    tdf.to_csv('provider_data/' + prvdr + '.csv')

# %%
main_df4.to_pickle('all_data/HCRIS.pkl')

# %%
report_categories = list(set(main_df4.columns.get_level_values(2).tolist()))
report_categories = [x for x in report_categories if str(x) != 'nan']
report_categories = [x for x in report_categories if str(x) != 'Lat']
report_categories = [x for x in report_categories if str(x) != 'Lon']
report_categories = [x for x in report_categories if str(x) != 'Lon']
report_categories = [x for x in report_categories if str(x) != 'Num and Name']
report_categories = [x for x in report_categories if str(x) != 'Hospital type, text']
report_categories = [x for x in report_categories if str(x) != '']
report_categories = [x for x in report_categories if str(x) != 'HOSPITAL IDENTIFICATION INFORMATION']

report_categories = [x for x in report_categories if str(x) != 'Control type, text']
report_categories = [x for x in report_categories if str(x) != 'HOSPITAL IDENTIFICATION INFORMATION']
report_categories = [x for x in report_categories if str(x) != 'HOSPITAL IDENTIFICATION INFORMATION']
report_categories.sort()

import csv

with open('GenDat4App/report_categories.csv', 'w+', newline='') as OUT:
    writer = csv.writer(OUT)
    writer.writerow(report_categories)
    
    
sub_categories = list(set(main_df4.columns.get_level_values(3).tolist()))
sub_categories.sort()

with open('GenDat4App/sub_categories.csv', 'w+', newline='') as OUT:
    writer = csv.writer(OUT)
    writer.writerow(sub_categories)
